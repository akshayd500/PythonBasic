# %% [markdown]
# # Our Frist NoteBook Program

# %% [markdown]
# ## Program to read and work with Pandas Package1

# %%
import pandas as pd
data = pd.read_csv("Boston.csv")

# %% [markdown]
# shows top 5 values

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 0             1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900
# 1             2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671
# 2             3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671
# 3             4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622
# 4             5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622
# 5             6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622
# 6             7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605
# 7             8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505
# 8             9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821
# 9            10   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921
# 10           11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467
# 11           12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267
# ...

# %%
data["nox"]
# Out:
# 0      0.538
# 1      0.469
# 2      0.469
# 3      0.458
# 4      0.458
# 5      0.458
# 6      0.524
# 7      0.524
# 8      0.524
# 9      0.524
# 10     0.524
# 11     0.524
# 12     0.524
# 13     0.538
# 14     0.538
# 15     0.538
# 16     0.538
# 17     0.538
# 18     0.538
# 19     0.538
# 20     0.538
# 21     0.538
# 22     0.538
# 23     0.538
# 24     0.538
# 25     0.538
# 26     0.538
# 27     0.538
# 28     0.538
# 29     0.538
#        ...
# 476    0.614
# 477    0.614
# 478    0.614
# 479    0.614
# 480    0.532
# 481    0.532
# 482    0.532
# 483    0.532
# 484    0.583
# 485    0.583
# 486    0.583
# 487    0.583
# 488    0.609
# 489    0.609
# 490    0.609
# 491    0.609
# 492    0.609
# 493    0.585
# 494    0.585
# 495    0.585
# 496    0.585
# 497    0.585
# 498    0.585
# 499    0.585
# 500    0.585
# 501    0.573
# 502    0.573
# 503    0.573
# 504    0.573
# 505    0.573
# Name: nox, Length: 506, dtype: float64

# %%
data[["nox",'crim']]
# Out:
#        nox      crim
# 0    0.538   0.00632
# 1    0.469   0.02731
# 2    0.469   0.02729
# 3    0.458   0.03237
# 4    0.458   0.06905
# 5    0.458   0.02985
# 6    0.524   0.08829
# 7    0.524   0.14455
# 8    0.524   0.21124
# 9    0.524   0.17004
# 10   0.524   0.22489
# 11   0.524   0.11747
# 12   0.524   0.09378
# 13   0.538   0.62976
# 14   0.538   0.63796
# 15   0.538   0.62739
# 16   0.538   1.05393
# 17   0.538   0.78420
# 18   0.538   0.80271
# 19   0.538   0.72580
# 20   0.538   1.25179
# 21   0.538   0.85204
# 22   0.538   1.23247
# 23   0.538   0.98843
# 24   0.538   0.75026
# 25   0.538   0.84054
# 26   0.538   0.67191
# 27   0.538   0.95577
# 28   0.538   0.77299
# 29   0.538   1.00245
# ..     ...       ...
# 476  0.614   4.87141
# 477  0.614  15.02340
# 478  0.614  10.23300
# 479  0.614  14.33370
# 480  0.532   5.82401
# 481  0.532   5.70818
# 482  0.532   5.73116
# 483  0.532   2.81838
# 484  0.583   2.37857
# 485  0.583   3.67367
# 486  0.583   5.69175
# ...

# %%
sdata = data[["nox",'age','ptratio','tax']]
sdata[100:190]
# Out:
#        nox   age  ptratio  tax
# 100  0.520  79.9     20.9  384
# 101  0.520  71.3     20.9  384
# 102  0.520  85.4     20.9  384
# 103  0.520  87.4     20.9  384
# 104  0.520  90.0     20.9  384
# 105  0.520  96.7     20.9  384
# 106  0.520  91.9     20.9  384
# 107  0.520  85.2     20.9  384
# 108  0.520  97.1     20.9  384
# 109  0.520  91.2     20.9  384
# 110  0.520  54.4     20.9  384
# 111  0.547  81.6     17.8  432
# 112  0.547  92.9     17.8  432
# 113  0.547  95.4     17.8  432
# 114  0.547  84.2     17.8  432
# 115  0.547  88.2     17.8  432
# 116  0.547  72.5     17.8  432
# 117  0.547  82.6     17.8  432
# 118  0.547  73.1     17.8  432
# 119  0.547  65.2     17.8  432
# 120  0.581  69.7     19.1  188
# 121  0.581  84.1     19.1  188
# 122  0.581  92.9     19.1  188
# 123  0.581  97.0     19.1  188
# 124  0.581  95.8     19.1  188
# 125  0.581  88.4     19.1  188
# 126  0.581  95.6     19.1  188
# 127  0.624  96.0     21.2  437
# 128  0.624  98.8     21.2  437
# ...

# %%
sdata.head()
# Out:
#      nox   age  ptratio  tax
# 0  0.538  65.2     15.3  296
# 1  0.469  78.9     17.8  242
# 2  0.469  61.1     17.8  242
# 3  0.458  45.8     18.7  222
# 4  0.458  54.2     18.7  222

# %%
# !ls
# Out:
# 'abc (copy).jpeg'   a.py.save.2      IMAGE.py		     Small_boston.csv
#  abc.jpeg	   'b (copy).jpeg'   new.jpg		     strip.py
#  a.jpeg		    b.jpeg	     q.py		     tri.jpg
#  a.py		    Boston.csv	     README.md		     tri.py
#  a.py.save	    b.py	     red.jpg		     Untitled.ipynb
#  a.py.save.1	    chess.jpg	     six-red-roses-274.jpg   z.jpg

# %%
sdata.to_csv("Small_boston.csv")

# %%
sdata.iloc[3]
# Out:
# nox          0.458
# age         45.800
# ptratio     18.700
# tax        222.000
# Name: 3, dtype: float64

# %%
age40=sdata[sdata['age']>40]

# %%
a,b=age40.shape[0],sdata.shape[0]

# %%
a
# Out:
# 397

# %%
b
# Out:
# 506

# %%
a/b*100
# Out:
# 78.45849802371542

# %%
sdata.shape[0]
# Out:
# 506

# %%
sdata.head()
# Out:
#      nox   age  ptratio  tax
# 0  0.538  65.2     15.3  296
# 1  0.469  78.9     17.8  242
# 2  0.469  61.1     17.8  242
# 3  0.458  45.8     18.7  222
# 4  0.458  54.2     18.7  222
